# %% [markdown]
# # Matplotlib e Pandas
#
# O Pandas é uma biblioteca que permite a manipulação de dados de forma simples e eficiente. Ela é construída sobre o NumPy e permite a manipulação de dados de forma simples e eficiente. Quanto a gráficos, o Pandas utiliza o Matplotlib como base para a geração de gráficos.

# %% [markdown]
# ## Base de dados utilizada
#
# Para este notebook, utilizaremos a base de dados do top 10 IBOV de maio a agosto de 2023. A base de dados foi obtida no site do Yahoo Finance. O IBOV é o índice da Bovespa, que é a bolsa de valores brasileira. O IBOV é composto pelas ações mais negociadas na bolsa de valores brasileira. Para compor o IBOV, é feito um cálculo de ponderação das ações, onde as ações mais negociadas possuem maior peso no índice. O IBOV é um índice que é utilizado para medir o desempenho médio das cotações das ações mais negociadas na bolsa de valores brasileira.
#
# Este material é didático e não tem como objetivo a recomendação de compra ou venda de ativos.
#
# Sobre as ações seguem os nomes referentes a cada uma delas e seus respectivos setores:
#
# Código | Nome | Setor
# --- | --- | ---
#  VALE3 | Vale | Mineração
#  ELET3 | Eletrobras | Energia Elétrica
#  BBAS3 | Banco do Brasil | Bancário
#  B3SA3 | B3 | Financeiro
#  ABEV3 | Ambev | Bebidas
#  ITUB4 | Itaú Unibanco | Bancário
#  BBDC4 | Bradesco | Bancário
#  WEGE3 | Weg | Máquinas e Equipamentos
#  PETR3 | Petrobras | Petróleo, Gás e Biocombustíveis
#  RENT3 | Localiza | Locação de Veículos

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('bmh')

ARQUIVO_TOP_10_IBOV = './assets/top_10_ibov_mai_ago_2023.csv'

df_top_10_ibov = pd.read_csv(ARQUIVO_TOP_10_IBOV)
df_top_10_ibov['Date'] = pd.to_datetime(df_top_10_ibov['Date'], format='%Y-%m-%d')
df_top_10_ibov = df_top_10_ibov.set_index('Date', drop=True)
df_top_10_ibov.head()
# Out:
#                 VALE3      ELET3      BBAS3      B3SA3  ABEV3      ITUB4  \
# Date
# 2023-01-02  87.478874  40.327332  31.615412  12.039818  14.19  23.893169
# 2023-01-03  87.322311  39.572250  31.026070  11.636853  14.17  23.395597
# 2023-01-04  87.478874  40.635326  31.425303  11.725308  14.25  23.463890
# 2023-01-05  88.946640  40.714806  32.860638  12.088961  14.29  24.195612
# 2023-01-06  90.355698  40.734676  33.316906  12.373984  14.32  24.615131
#
#                 BBDC4      WEGE3      PETR3      RENT3
# Date
# 2023-01-02  13.879215  37.771538  22.264847  50.636215
# 2023-01-03  13.190460  36.829731  21.950058  49.391312
# 2023-01-04  13.228148  37.077576  22.315893  49.974247
# 2023-01-05  13.802876  37.156883  23.039053  50.389210
# 2023-01-06  14.189168  37.702141  22.894421  51.347595

# %%
df_top_10_ibov.describe()
# Out:
#             VALE3       ELET3       BBAS3       B3SA3       ABEV3       ITUB4  \
# count  123.000000  123.000000  123.000000  123.000000  123.000000  123.000000
# mean    78.611862   36.116596   40.483970   12.228990   14.181789   25.451306
# std      9.373119    3.229293    4.710353    1.302324    0.674569    1.527655
# min     63.810001   30.332432   31.026070   10.246643   12.860000   22.617268
# 25%     69.049999   33.535763   37.366261   11.215220   13.615000   24.360209
# 50%     80.290001   35.320000   39.086395   11.921384   14.290000   25.315250
# 75%     86.666714   39.080000   42.888365   13.086743   14.610000   26.384904
# max     95.894073   42.473354   51.990002   15.095129   15.550000   29.021967
#
#             BBDC4       WEGE3       PETR3       RENT3
# count  123.000000  123.000000  123.000000  123.000000
# mean    14.236140   38.677956   26.009727   57.682620
# std      1.310557    1.249857    3.457692    5.167213
# min     12.355516   36.342026   21.754379   49.391312
# 25%     13.209580   37.657532   23.630344   53.502365
# 50%     13.731629   38.698261   25.157490   56.580109
# 75%     15.382814   39.606815   27.468965   61.624264
# max     17.064342   41.793327   35.680000   67.951851

# %%
fig, ax = plt.subplots(figsize=(10, 7))

df_top_10_ibov.plot(ax = ax)
ax.set_title('Top 10 IBOV')

plt.show()

# %%
axes = df_top_10_ibov.plot(figsize=(10, 12), title='Top 10 - IBOV', subplots=True, layout=(5, 2))

# Removendo os xticks de cada subplot
# for ax in axes.flatten():
#     ax.set_xticks([])

# plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots()

ax.plot(df_top_10_ibov.index, df_top_10_ibov['BBDC4'], label='BBDC4')
ax.plot(df_top_10_ibov.index, df_top_10_ibov['ITUB4'], label='ITUB4')
ax.plot(df_top_10_ibov.index, df_top_10_ibov['BBAS3'], label='BBAS3')
ax.legend()

# ax.set_xticks([])
ax.set_title('Comparando bancos do top 10 IBOV')
ax.set_ylabel('Valor em R$')

plt.show()

# %%
variacao_diaria = df_top_10_ibov.pct_change()
variacao_diaria.head(5)
# Out:
#                VALE3     ELET3     BBAS3     B3SA3     ABEV3     ITUB4  \
# Date
# 2023-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2023-01-03 -0.001790 -0.018724 -0.018641 -0.033469 -0.001409 -0.020825
# 2023-01-04  0.001793  0.026864  0.012868  0.007601  0.005646  0.002919
# 2023-01-05  0.016779  0.001956  0.045675  0.031014  0.002807  0.031185
# 2023-01-06  0.015842  0.000488  0.013885  0.023577  0.002099  0.017339
#
#                BBDC4     WEGE3     PETR3     RENT3
# Date
# 2023-01-02       NaN       NaN       NaN       NaN
# 2023-01-03 -0.049625 -0.024934 -0.014138 -0.024585
# 2023-01-04  0.002857  0.006729  0.016667  0.011802
# 2023-01-05  0.043447  0.002139  0.032406  0.008304
# 2023-01-06  0.027986  0.014674 -0.006278  0.019020

# %%
fig, ax = plt.subplots()

variacao_diaria = df_top_10_ibov.pct_change()
ax.plot(variacao_diaria.index, variacao_diaria['BBDC4'], label='BBDC4')
ax.plot(variacao_diaria.index, variacao_diaria['ITUB4'], label='ITUB4')
ax.plot(variacao_diaria.index, variacao_diaria['BBAS3'], label='BBAS3')
ax.legend()

ax.set_title('Comparando a variação diária do top 10 IBOV')
ax.set_ylabel('Variação %')

plt.show()

# %%
fig, axs = plt.subplots(nrows=3, ncols=1, figsize=(10, 8), sharex=True)

bancos = ['BBDC4', 'ITUB4', 'BBAS3']
variacao_diaria = df_top_10_ibov.pct_change()

for i, banco in enumerate(bancos):
    axs[i].plot(variacao_diaria.index, variacao_diaria[banco], label=banco, color=f'C{i}')
    axs[i].legend()

fig.suptitle('Comparando a variação diária dos bandcos BBDC ITUB BBAS')
fig.supylabel('Variação percentual')

plt.show()

# %%
fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(10, 6))

axs[0].scatter('BBDC4', 'BBAS3', data=df_top_10_ibov)
axs[0].set_xlabel('BBDC4')
axs[0].set_ylabel('BBAS3')
axs[0].set_title('BBDC4 x BBAS3')

axs[1].scatter('BBDC4', 'ITUB4', data=df_top_10_ibov)
axs[1].set_xlabel('BBDC4')
axs[1].set_ylabel('ITUB4')
axs[1].set_title('BBDC4 x ITUB4')

axs[2].scatter('BBAS3', 'ITUB4', data=df_top_10_ibov)
axs[2].set_xlabel('BBAS3')
axs[2].set_ylabel('ITUB4')
axs[2].set_title('BBAS3 x ITUB4')

plt.suptitle('Analisando a correlação dos bancos')

plt.show()

# %%
from itertools import combinations

fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(10, 6))

bancos = ['BBDC4', 'ITUB4', 'BBAS3']
pares_bancos = list(combinations(bancos, 2))
# print(pares_bancos)

for i, par in enumerate(pares_bancos):
    # print(par)
    axs[i].scatter(par[0], par[1], data=df_top_10_ibov)
    axs[i].set_xlabel(par[0])
    axs[i].set_ylabel(par[1])
    axs[i].set_title(f'{par[0]} x {par[1]}')

    
plt.suptitle('Analisando a correlação dos bancos')

plt.show()

# %%
df_top_10_ibov.corr().style.background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style type="text/css">
# #T_1bc67_row0_col0, #T_1bc67_row1_col1, #T_1bc67_row2_col2, #T_1bc67_row3_col3, #T_1bc67_row4_col4, #T_1bc67_row5_col5, #T_1bc67_row6_col6, #T_1bc67_row7_col7, #T_1bc67_row8_col8, #T_1bc67_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_1bc67_row0_col1, #T_1bc67_row1_col0 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_1bc67_row0_col2, #T_1bc67_row2_col0 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_1bc67_row0_col3, #T_1bc67_row3_col0 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_1bc67_row0_col4, #T_1bc67_row4_col0 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_1bc67_row0_col5, #T_1bc67_row5_col0 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_1bc67_row0_col6, #T_1bc67_row6_col0 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_1bc67_row0_col7, #T_1bc67_row7_col0 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_1bc67_row0_col8, #T_1bc67_row8_col0 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_1bc67_row0_col9, #T_1bc67_row9_col0 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_1bc67_row1_col2, #T_1bc67_row2_col1 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_1bc67_row1_col3, #T_1bc67_row3_col1 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_1bc67_row1_col4, #T_1bc67_row4_col1 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_1bc67_row1_col5, #T_1bc67_row5_col1 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_1bc67_row1_col6, #T_1bc67_row6_col1 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_1bc67_row1_col7, #T_1bc67_row7_col1 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_1bc67_row1_col8, #T_1bc67_row8_col1 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_1bc67_row1_col9, #T_1bc67_row9_col1 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_1bc67_row2_col3, #T_1bc67_row2_col4, #T_1bc67_row3_col2, #T_1bc67_row4_col2, #T_1bc67_row4_col6, #T_1bc67_row6_col4 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_1bc67_row2_col5, #T_1bc67_row5_col2, #T_1bc67_row6_col8, #T_1bc67_row8_col6 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_1bc67_row2_col6, #T_1bc67_row6_col2 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_1bc67_row2_col7, #T_1bc67_row7_col2 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_1bc67_row2_col8, #T_1bc67_row8_col2 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_1bc67_row2_col9, #T_1bc67_row5_col9, #T_1bc67_row9_col2, #T_1bc67_row9_col5 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_1bc67_row3_col4, #T_1bc67_row4_col3, #T_1bc67_row4_col5, #T_1bc67_row5_col4 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_1bc67_row3_col5, #T_1bc67_row3_col8, #T_1bc67_row5_col3, #T_1bc67_row8_col3 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_1bc67_row3_col6, #T_1bc67_row6_col3 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_1bc67_row3_col7, #T_1bc67_row7_col3 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_1bc67_row3_col9, #T_1bc67_row9_col3 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_1bc67_row4_col7, #T_1bc67_row7_col4 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_1bc67_row4_col8, #T_1bc67_row8_col4 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_1bc67_row4_col9, #T_1bc67_row9_col4 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_1bc67_row5_col6, #T_1bc67_row6_col5, #T_1bc67_row6_col9, #T_1bc67_row9_col6 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_1bc67_row5_col7, #T_1bc67_row7_col5 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_1bc67_row5_col8, #T_1bc67_row8_col5 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_1bc67_row6_col7, #T_1bc67_row7_col6 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_1bc67_row7_col8, #T_1bc67_row8_col7 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_1bc67_row7_col9, #T_1bc67_row9_col7 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_1bc67_row8_col9, #T_1bc67_row9_col8 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1bc67">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1bc67_level0_col0" class="col_heading level0 col0" >VALE3</th>
#       <th id="T_1bc67_level0_col1" class="col_heading level0 col1" >ELET3</th>
#       <th id="T_1bc67_level0_col2" class="col_heading level0 col2" >BBAS3</th>
#       <th id="T_1bc67_level0_col3" class="col_heading level0 col3" >B3SA3</th>
#       <th id="T_1bc67_level0_col4" class="col_heading level0 col4" >ABEV3</th>
#       <th id="T_1bc67_level0_col5" class="col_heading level0 col5" >ITUB4</th>
#       <th id="T_1bc67_level0_col6" class="col_heading level0 col6" >BBDC4</th>
#       <th id="T_1bc67_level0_col7" class="col_heading level0 col7" >WEGE3</th>
#       <th id="T_1bc67_level0_col8" class="col_heading level0 col8" >PETR3</th>
#       <th id="T_1bc67_level0_col9" class="col_heading level0 col9" >RENT3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1bc67_level0_row0" class="row_heading level0 row0" >VALE3</th>
#       <td id="T_1bc67_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_1bc67_row0_col1" class="data row0 col1" >0.254017</td>
#       <td id="T_1bc67_row0_col2" class="data row0 col2" >-0.801388</td>
#       <td id="T_1bc67_row0_col3" class="data row0 col3" >-0.472413</td>
#       <td id="T_1bc67_row0_col4" class="data row0 col4" >-0.733513</td>
#       <td id="T_1bc67_row0_col5" class="data row0 col5" >-0.616604</td>
#       <td id="T_1bc67_row0_col6" class="data row0 col6" >-0.630104</td>
#       <td id="T_1bc67_row0_col7" class="data row0 col7" >-0.114228</td>
#       <td id="T_1bc67_row0_col8" class="data row0 col8" >-0.649903</td>
#       <td id="T_1bc67_row0_col9" class="data row0 col9" >-0.699430</td>
#     </tr>
#     <tr>
#       <th id="T_1bc67_level0_row1" class="row_heading level0 row1" >ELET3</th>
#       <td id="T_1bc67_row1_col0" class="data row1 col0" >0.254017</td>
#       <td id="T_1bc67_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_1bc67_row1_col2" class="data row1 col2" >0.072803</td>
#       <td id="T_1bc67_row1_col3" class="data row1 col3" >0.641147</td>
#       <td id="T_1bc67_row1_col4" class="data row1 col4" >0.089652</td>
#       <td id="T_1bc67_row1_col5" class="data row1 col5" >0.421773</td>
#       <td id="T_1bc67_row1_col6" class="data row1 col6" >0.476954</td>
#       <td id="T_1bc67_row1_col7" class="data row1 col7" >-0.748048</td>
#       <td id="T_1bc67_row1_col8" class="data row1 col8" >0.350004</td>
#       <td id="T_1bc67_row1_col9" class="data row1 col9" >0.331517</td>
#     </tr>
#     <tr>
#       <th id="T_1bc67_level0_row2" class="row_heading level0 row2" >BBAS3</th>
#       <td id="T_1bc67_row2_col0" class="data row2 col0" >-0.801388</td>
#       <td id="T_1bc67_row2_col1" class="data row2 col1" >0.072803</td>
#       <td id="T_1bc67_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_1bc67_row2_col3" class="data row2 col3" >0.665027</td>
#       <td id="T_1bc67_row2_col4" class="data row2 col4" >0.666072</td>
#       <td id="T_1bc67_row2_col5" class="data row2 col5" >0.858388</td>
#       <td id="T_1bc67_row2_col6" class="data row2 col6" >0.753427</td>
#       <td id="T_1bc67_row2_col7" class="data row2 col7" >-0.213368</td>
#       <td id="T_1bc67_row2_col8" class="data row2 col8" >0.924637</td>
#       <td id="T_1bc67_row2_col9" class="data row2 col9" >0.895541</td>
#     </tr>
#     <tr>
#       <th id="T_1bc67_level0_row3" class="row_heading level0 row3" >B3SA3</th>
#       <td id="T_1bc67_row3_col0" class="data row3 col0" >-0.472413</td>
#       <td id="T_1bc67_row3_col1" class="data row3 col1" >0.641147</td>
#       <td id="T_1bc67_row3_col2" class="data row3 col2" >0.665027</td>
#       <td id="T_1bc67_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_1bc67_row3_col4" class="data row3 col4" >0.576847</td>
#       <td id="T_1bc67_row3_col5" class="data row3 col5" >0.806739</td>
#       <td id="T_1bc67_row3_col6" class="data row3 col6" >0.932840</td>
#       <td id="T_1bc67_row3_col7" class="data row3 col7" >-0.575233</td>
#       <td id="T_1bc

# %%
df_top_10_ibov.corr().style.format(precision=2).background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style type="text/css">
# #T_08e24_row0_col0, #T_08e24_row1_col1, #T_08e24_row2_col2, #T_08e24_row3_col3, #T_08e24_row4_col4, #T_08e24_row5_col5, #T_08e24_row6_col6, #T_08e24_row7_col7, #T_08e24_row8_col8, #T_08e24_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_08e24_row0_col1, #T_08e24_row1_col0 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_08e24_row0_col2, #T_08e24_row2_col0 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_08e24_row0_col3, #T_08e24_row3_col0 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_08e24_row0_col4, #T_08e24_row4_col0 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_08e24_row0_col5, #T_08e24_row5_col0 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_08e24_row0_col6, #T_08e24_row6_col0 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_08e24_row0_col7, #T_08e24_row7_col0 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_08e24_row0_col8, #T_08e24_row8_col0 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_08e24_row0_col9, #T_08e24_row9_col0 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_08e24_row1_col2, #T_08e24_row2_col1 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_08e24_row1_col3, #T_08e24_row3_col1 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_08e24_row1_col4, #T_08e24_row4_col1 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_08e24_row1_col5, #T_08e24_row5_col1 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_08e24_row1_col6, #T_08e24_row6_col1 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_08e24_row1_col7, #T_08e24_row7_col1 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_08e24_row1_col8, #T_08e24_row8_col1 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_08e24_row1_col9, #T_08e24_row9_col1 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_08e24_row2_col3, #T_08e24_row2_col4, #T_08e24_row3_col2, #T_08e24_row4_col2, #T_08e24_row4_col6, #T_08e24_row6_col4 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_08e24_row2_col5, #T_08e24_row5_col2, #T_08e24_row6_col8, #T_08e24_row8_col6 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_08e24_row2_col6, #T_08e24_row6_col2 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_08e24_row2_col7, #T_08e24_row7_col2 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_08e24_row2_col8, #T_08e24_row8_col2 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_08e24_row2_col9, #T_08e24_row5_col9, #T_08e24_row9_col2, #T_08e24_row9_col5 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_08e24_row3_col4, #T_08e24_row4_col3, #T_08e24_row4_col5, #T_08e24_row5_col4 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_08e24_row3_col5, #T_08e24_row3_col8, #T_08e24_row5_col3, #T_08e24_row8_col3 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_08e24_row3_col6, #T_08e24_row6_col3 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_08e24_row3_col7, #T_08e24_row7_col3 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_08e24_row3_col9, #T_08e24_row9_col3 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_08e24_row4_col7, #T_08e24_row7_col4 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_08e24_row4_col8, #T_08e24_row8_col4 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_08e24_row4_col9, #T_08e24_row9_col4 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_08e24_row5_col6, #T_08e24_row6_col5, #T_08e24_row6_col9, #T_08e24_row9_col6 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_08e24_row5_col7, #T_08e24_row7_col5 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_08e24_row5_col8, #T_08e24_row8_col5 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_08e24_row6_col7, #T_08e24_row7_col6 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_08e24_row7_col8, #T_08e24_row8_col7 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_08e24_row7_col9, #T_08e24_row9_col7 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_08e24_row8_col9, #T_08e24_row9_col8 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_08e24">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_08e24_level0_col0" class="col_heading level0 col0" >VALE3</th>
#       <th id="T_08e24_level0_col1" class="col_heading level0 col1" >ELET3</th>
#       <th id="T_08e24_level0_col2" class="col_heading level0 col2" >BBAS3</th>
#       <th id="T_08e24_level0_col3" class="col_heading level0 col3" >B3SA3</th>
#       <th id="T_08e24_level0_col4" class="col_heading level0 col4" >ABEV3</th>
#       <th id="T_08e24_level0_col5" class="col_heading level0 col5" >ITUB4</th>
#       <th id="T_08e24_level0_col6" class="col_heading level0 col6" >BBDC4</th>
#       <th id="T_08e24_level0_col7" class="col_heading level0 col7" >WEGE3</th>
#       <th id="T_08e24_level0_col8" class="col_heading level0 col8" >PETR3</th>
#       <th id="T_08e24_level0_col9" class="col_heading level0 col9" >RENT3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_08e24_level0_row0" class="row_heading level0 row0" >VALE3</th>
#       <td id="T_08e24_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_08e24_row0_col1" class="data row0 col1" >0.25</td>
#       <td id="T_08e24_row0_col2" class="data row0 col2" >-0.80</td>
#       <td id="T_08e24_row0_col3" class="data row0 col3" >-0.47</td>
#       <td id="T_08e24_row0_col4" class="data row0 col4" >-0.73</td>
#       <td id="T_08e24_row0_col5" class="data row0 col5" >-0.62</td>
#       <td id="T_08e24_row0_col6" class="data row0 col6" >-0.63</td>
#       <td id="T_08e24_row0_col7" class="data row0 col7" >-0.11</td>
#       <td id="T_08e24_row0_col8" class="data row0 col8" >-0.65</td>
#       <td id="T_08e24_row0_col9" class="data row0 col9" >-0.70</td>
#     </tr>
#     <tr>
#       <th id="T_08e24_level0_row1" class="row_heading level0 row1" >ELET3</th>
#       <td id="T_08e24_row1_col0" class="data row1 col0" >0.25</td>
#       <td id="T_08e24_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_08e24_row1_col2" class="data row1 col2" >0.07</td>
#       <td id="T_08e24_row1_col3" class="data row1 col3" >0.64</td>
#       <td id="T_08e24_row1_col4" class="data row1 col4" >0.09</td>
#       <td id="T_08e24_row1_col5" class="data row1 col5" >0.42</td>
#       <td id="T_08e24_row1_col6" class="data row1 col6" >0.48</td>
#       <td id="T_08e24_row1_col7" class="data row1 col7" >-0.75</td>
#       <td id="T_08e24_row1_col8" class="data row1 col8" >0.35</td>
#       <td id="T_08e24_row1_col9" class="data row1 col9" >0.33</td>
#     </tr>
#     <tr>
#       <th id="T_08e24_level0_row2" class="row_heading level0 row2" >BBAS3</th>
#       <td id="T_08e24_row2_col0" class="data row2 col0" >-0.80</td>
#       <td id="T_08e24_row2_col1" class="data row2 col1" >0.07</td>
#       <td id="T_08e24_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_08e24_row2_col3" class="data row2 col3" >0.67</td>
#       <td id="T_08e24_row2_col4" class="data row2 col4" >0.67</td>
#       <td id="T_08e24_row2_col5" class="data row2 col5" >0.86</td>
#       <td id="T_08e24_row2_col6" class="data row2 col6" >0.75</td>
#       <td id="T_08e24_row2_col7" class="data row2 col7" >-0.21</td>
#       <td id="T_08e24_row2_col8" class="data row2 col8" >0.92</td>
#       <td id="T_08e24_row2_col9" class="data row2 col9" >0.90</td>
#     </tr>
#     <tr>
#       <th id="T_08e24_level0_row3" class="row_heading level0 row3" >B3SA3</th>
#       <td id="T_08e24_row3_col0" class="data row3 col0" >-0.47</td>
#       <td id="T_08e24_row3_col1" class="data row3 col1" >0.64</td>
#       <td id="T_08e24_row3_col2" class="data row3 col2" >0.67</td>
#       <td id="T_08e24_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_08e24_row3_col4" class="data row3 col4" >0.58</td>
#       <td id="T_08e24_row3_col5" class="data row3 col5" >0.81</td>
#       <td id="T_08e24_row3_col6" class="data row3 col6" >0.93</td>
#       <td id="T_08e24_row3_col7" class="data row3 col7" >-0.58</td>
#       <td id="T_08e24_row3_col8" class="data row3 col8" >0.81</td>
#       <td id="T_08e24_row3_col9" class="data row3 col9" >0.86</td>
#     </tr>
#     <tr>
#       <th id="T_08

# %%
df_top_10_ibov[bancos].corr().style.format(precision=2).background_gradient(cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <style type="text/css">
# #T_3be14_row0_col0, #T_3be14_row1_col1, #T_3be14_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_3be14_row0_col1, #T_3be14_row1_col0 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_3be14_row0_col2, #T_3be14_row2_col0 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_3be14_row1_col2, #T_3be14_row2_col1 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3be14">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3be14_level0_col0" class="col_heading level0 col0" >BBDC4</th>
#       <th id="T_3be14_level0_col1" class="col_heading level0 col1" >ITUB4</th>
#       <th id="T_3be14_level0_col2" class="col_heading level0 col2" >BBAS3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3be14_level0_row0" class="row_heading level0 row0" >BBDC4</th>
#       <td id="T_3be14_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_3be14_row0_col1" class="data row0 col1" >0.88</td>
#       <td id="T_3be14_row0_col2" class="data row0 col2" >0.75</td>
#     </tr>
#     <tr>
#       <th id="T_3be14_level0_row1" class="row_heading level0 row1" >ITUB4</th>
#       <td id="T_3be14_row1_col0" class="data row1 col0" >0.88</td>
#       <td id="T_3be14_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_3be14_row1_col2" class="data row1 col2" >0.86</td>
#     </tr>
#     <tr>
#       <th id="T_3be14_level0_row2" class="row_heading level0 row2" >BBAS3</th>
#       <td id="T_3be14_row2_col0" class="data row2 col0" >0.75</td>
#       <td id="T_3be14_row2_col1" class="data row2 col1" >0.86</td>
#       <td id="T_3be14_row2_col2" class="data row2 col2" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 
from pandas.plotting import scatter_matrix

scatter_matrix(df_top_10_ibov, figsize=(12, 12), hist_kwds={'bins': 10, 'edgecolor': 'black'});
