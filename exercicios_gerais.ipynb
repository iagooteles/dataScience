# %% [markdown]
# ## Exercício para os três tipos básicos de gráficos
#
# Você recebeu, na forma de listas, os dados de receita anual de uma empresa de tecnologia, em bilhões de dólares, nos últimos anos. Com esses dados, você deve criar três gráficos, um de cada tipo abaixo listado, para visualizar esses dados. Os gráficos devem conter título e rótulos dos eixos. O nome da empresa é "Apple Inc.".
#
# Tipos de gráficos:
#
# - Gráfico de linhas
#   - além da linha, mostre os pontos de cada valor
# - Gráfico de barras
#   - adicione o valor de cada barra no gráfico
# - Gráfico de dispersão
#   - ligue a grade do gráfico
#
# Cada gráfico deve usar uma paleta de cores diferente.
#
# Os dados são:
#
# Ano | Receita (em bilhões de dólares)
# --- | ---
# | 2009 | 42,9
# | 2010 | 65,2
# | 2011 | 108,2
# | 2012 | 156,5
# | 2013 | 170,9
# | 2014 | 182,8
# | 2015 | 233,7
# | 2016 | 215,6
# | 2017 | 229,2
# | 2018 | 265,6
# | 2019 | 260,2
# | 2020 | 274,5
# | 2021 | 365,8
# | 2022 | 394,3
#
# Qual o tipo de gráfico mais adequado para visualizar esses dados?

# %% [markdown]
# ## Gráfico de linhas

# %%
# convertendo os dados para listas
ano = [2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
receita = [42.9, 65.2, 108.2, 156.5, 170.9, 182.8, 233.7, 215.6, 229.2, 265.6, 260.2, 274.5, 365.8, 394.3]
receita_menor = [32.9, 55.2, 78.2, 126.0, 140, 152.1, 90.7, 186, 199, 235.1, 230.7, 244.5, 335.8, 364.3]

# %%
# gráfico de linhas
from matplotlib.rcsetup import cycler
import pandas as pd
import matplotlib.pyplot as plt

dados_dict = {'Ano': ano, 'Receita': receita, 'Receita menor': receita_menor}
df = pd.DataFrame(dados_dict)

cores = plt.get_cmap('tab10').colors
ciclo_cores = cycler('color', cores)

plt.figure(figsize=(12, 5))
plt.plot(df['Ano'], df['Receita'], marker='o')
plt.plot(df['Ano'], df['Receita menor'], marker='x')

plt.title('Evolução anual da Apple Inc')
plt.xlabel('Ano')
plt.ylabel('Vendas em milhares')

plt.ylim(0, df['Receita'].max() + 50)

plt.xticks(ano, rotation=45)

for x, y in zip(ano, receita):
    plt.text(x, y + 20, f'{y:.1f}', ha='center', va='bottom')

for x, y in zip(ano, receita_menor):
    plt.text(x, y - 50, f'{y:.1f}', ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Gráfico de Barras

# %%
# gráfico de barras #

ano = [2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
receita = [42.9, 65.2, 108.2, 156.5, 170.9, 182.8, 233.7, 215.6, 229.2, 265.6, 260.2, 274.5, 365.8, 394.3]
receita_menor = [32.9, 55.2, 78.2, 126.0, 140, 152.1, 90.7, 186, 199, 235.1, 230.7, 244.5, 335.8, 364.3]

# %%
from cycler import cycler
import pandas as pd
import matplotlib.pyplot as plt

dados_dict = {'Ano': ano, 'Receita': receita, 'Receita menor': receita_menor}
df = pd.DataFrame(dados_dict)

df
# Out:
#      Ano  Receita  Receita menor
# 0   2009     42.9           32.9
# 1   2010     65.2           55.2
# 2   2011    108.2           78.2
# 3   2012    156.5          126.0
# 4   2013    170.9          140.0
# 5   2014    182.8          152.1
# 6   2015    233.7           90.7
# 7   2016    215.6          186.0
# 8   2017    229.2          199.0
# 9   2018    265.6          235.1
# 10  2019    260.2          230.7
# 11  2020    274.5          244.5
# 12  2021    365.8          335.8
# 13  2022    394.3          364.3

# %%
plt.figure(figsize=(12,5))
barras = plt.bar(df['Ano'], df['Receita'])

cores = plt.get_cmap('Set3').colors
ciclo_cores = cycler('color', cores)
plt.rc('axes', prop_cycle=ciclo_cores)

plt.ylabel('Receita (em bilhoes de dolares)')
plt.xlabel('Ano')
plt.title('Evolução anual da apple inc')

plt.ylim(0, df['Receita'].max() + 50)
plt.xticks(ano, rotation=45)

plt.bar_label(barras)
# for x, y in zip(df['Ano'], df['Receita']):
#     plt.text(x, y + 5, f'{y:.1f}', ha='center')

plt.show()

# %% [markdown]
# ## Gráfico de dispersão

# %%
# Grafico de dispersão #
from cycler import cycler

cores = plt.get_cmap('Set1').colors
ciclo_cores = cycler('color', cores)
plt.rc('axes', prop_cycle=ciclo_cores)


plt.figure(figsize=(12,5))

plt.scatter(ano, receita)
plt.xticks(ano, rotation=45)

plt.grid(True, linestyle=':')

plt.ylabel('Receita (em bilhoes de dolares)')
plt.xlabel('Ano')
plt.title('Evolução anual da apple inc')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Grafico de dispersão #
from cycler import cycler

cores = plt.get_cmap('Set1').colors
ciclo_cores = cycler('color', cores)
plt.rc('axes', prop_cycle=ciclo_cores)


plt.figure(figsize=(12,5))

plt.scatter(ano, receita, s=receita, c=receita, cmap='Reds')
plt.colorbar()
plt.xticks(ano, rotation=45)


plt.grid(True, linestyle=':')

plt.ylabel('Receita (em bilhoes de dolares)')
plt.xlabel('Ano')
plt.title('Evolução anual da apple inc')
# Out:
# Text(0.5, 1.0, 'Evolução anual da apple inc')

# %% [markdown]
# ## Gráfico de pizza
#
# Você recebeu, na forma de listas, os dados de participação de mercado de fabricantes de smartphones. Com esses dados, você deve criar um gráfico de pizza, contendo título e rótulos das fatias, além das personalizações listadas abaixo. Os dados são:
#
# Fabricante | Participação de mercado (%)
# --- | ---
# | Samsung | 30,2
# | Apple | 26,6
# | Huawei | 10,4
# | Xiaomi | 9,7
# | Oppo | 4,8
# | Outros | 18,3
#
# Personalizações:
#
# - Paleta de cores diferente da padrão
# - Coloque os valores nas fatias
# - Destaque as fatias da Samsung e da Apple

# %%
# listas com os dados
fabricante = ['Samsung', 'Apple', 'Huawei', 'Xiaomi', 'Oppo', 'Outros']
participacao = [30.2, 26.6, 10.4, 9.7, 4.8, 18.3]

# %%
import matplotlib.pyplot as plt
import pandas as pd
from cycler import cycler

cores = plt.get_cmap('Set2').colors
ciclo_cores = cycler('color', cores)
plt.rc('axes', prop_cycle=ciclo_cores)

plt.title('Participação em % de mercado de fabricantes de smartphones')

plt.pie(x=participacao, labels=fabricante, autopct='%.1f', shadow=True,explode=(0.1, 0.05, 0, 0, 0, 0))

plt.show()
